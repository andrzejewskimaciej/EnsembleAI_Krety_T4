# %%
from software import load_image, plot_image
from software.preprocessing.image_aligner import straighten_image

# %%
img = load_image('./data/ecg_train_0002.png')
img.shape
# Out:
# (603, 781, 3)

# %%
plot_image(img)

# %%
straighten = straighten_image(img)

# %%
plot_image(straighten)
